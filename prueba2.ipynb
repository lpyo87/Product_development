# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np
from statsmodels.graphics.mosaicplot import mosaic
from dateutil import parser

# %%
df = pd.read_csv("Walmart.csv", sep=",")
columna_fecha = df['Date']

fechas_validas = []

for fecha in columna_fecha:
    try:
        fecha_parseada = parser.parse(fecha)
        fechas_validas.append(fecha_parseada)
    except ValueError:
        pass

if len(fechas_validas) > 0:
    print("Se encontraron fechas válidas en la columna:")
    for fecha in fechas_validas:
        print(fecha)
else:
    print("No se encontraron fechas válidas en la columna.")
# Out:
# Se encontraron fechas válidas en la columna:
# 2010-05-02 00:00:00
# 2010-12-02 00:00:00
# 2010-02-19 00:00:00
# 2010-02-26 00:00:00
# 2010-05-03 00:00:00
# 2010-12-03 00:00:00
# 2010-03-19 00:00:00
# 2010-03-26 00:00:00
# 2010-02-04 00:00:00
# 2010-09-04 00:00:00
# 2010-04-16 00:00:00
# 2010-04-23 00:00:00
# 2010-04-30 00:00:00
# 2010-07-05 00:00:00
# 2010-05-14 00:00:00
# 2010-05-21 00:00:00
# 2010-05-28 00:00:00
# 2010-04-06 00:00:00
# 2010-11-06 00:00:00
# 2010-06-18 00:00:00
# 2010-06-25 00:00:00
# 2010-02-07 00:00:00
# 2010-09-07 00:00:00
# 2010-07-16 00:00:00
# 2010-07-23 00:00:00
# 2010-07-30 00:00:00
# 2010-06-08 00:00:00
# 2010-08-13 00:00:00
# 2010-08-20 00:00:00
# 2010-08-27 00:00:00
# 2010-03-09 00:00:00
# 2010-10-09 00:00:00
# 2010-09-17 00:00:00
# 2010-09-24 00:00:00
# 2010-01-10 00:00:00
# 2010-08-10 00:00:00
# 2010-10-15 00:00:00
# 2010-10-22 00:00:00
# 2010-10-29 00:00:00
# 2010-05-11 00:00:00
# 2010-12-11 00:00:00
# 2010-11-19 00:00:00
# 2010-11-26 00:00:00
# ...
